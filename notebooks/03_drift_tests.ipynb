# %% [markdown]
# # Drift Detection
#
# In this notebook, we will perform drift detection by comparing the reference and mutated datasets.

# %%
from src.drift_detector import detect_drift_evidently, detect_drift_alibi
from src.data_loader import load_data

# Load datasets
data_ref = load_data('data/dataset.csv')
data_mut = load_data('data/mutated_dataset.csv')
X_ref, X_mut = data_ref['X'], data_mut['X']

# Perform drift detection
evidently_results = detect_drift_evidently(X_ref, X_mut)
alibi_results = detect_drift_alibi(X_ref, X_mut)

# Display results
print('Evidently Results:', evidently_results)
print('Alibi Results:', alibi_results)

# %% [markdown]
# ## Example Output
# The drift detection results have been displayed successfully.
